# %% [markdown]
# ## 使用其他井数据进行测试
#
# 发现问题，重新建模

# %%
import numpy as np
import pandas as pd
readpath = r'/home/klmyty/code/ML/data/溢流数据_clean/清洗后数据13_溢流.csv'
data = pd.read_csv(readpath,encoding='GBK')
data.head()
# Out:
#               时间  井深(8004) m  钻头位置(8005) m  迟到井深(8006) m  迟到时间(8007) min  \
# 0  2020/5/2 8:00      2357.1       2354.62       2350.01           50.63
# 1  2020/5/2 8:00      2357.1       2354.62       2350.01           51.27
# 2  2020/5/2 8:00      2357.1       2354.62       2350.01           51.52
# 3  2020/5/2 8:00      2357.1       2354.62       2350.01           51.17
# 4  2020/5/2 8:00      2357.1       2354.62       2350.01           50.68
#
#    大钩高度(8008) m  大钩速度(8009) m/s  大钩负荷(8010) kN  钻压(8011) kN  转盘转速(8012) RPM  \
# 0          6.98             0.0      991.20999          0.0        54.56000
# 1          6.98             0.0      995.31999          0.0        54.59000
# 2          6.98             0.0      998.00998          0.0        54.95999
# 3          6.98             0.0      996.30998          0.0        55.22998
# 4          6.98             0.0      996.16999          0.0        55.08999
#
# ...

# %%
data = data[['井深(8004) m', '迟到井深(8006) m', '大钩高度(8008) m', '全烃(8219) %', '入口温度(8106) DEG.C', '时间', '泵冲次1(8059) spm', '出口密度(8105) g/cm3', '套管压力(8019) MPa', '钻时(8020) min/m', '立管压力(8018) MPa', '钻压(8011) kN', '入口流量(8110) L/s', '出口温度(8107) DEG.C', '钻头位置(8005) m', '入口密度(8104) g/cm3', '扭矩(8013) kN.m', '大钩负荷(8010) kN', '总池体积(8112) m3', '溢流', '转盘转速(8012) RPM']]

# %% [markdown]
# ## onehot

# %%
encoded = pd.get_dummies(data,prefix=['kick'],columns=['溢流'])
encoded.head()
# Out:
#    井深(8004) m  迟到井深(8006) m  大钩高度(8008) m  全烃(8219) %  入口温度(8106) DEG.C  \
# 0  2962.02999    2958.93999      21.57461     1.11658           39.3488
# 1  2962.02999    2958.93999      21.56942     1.11697           39.3488
# 2  2962.02999    2958.93999      21.56942     1.11726           39.3488
# 3  2962.02999    2958.93999      21.56942     1.11766           39.3488
# 4  2962.03998    2958.93999      21.56412     1.11795           39.3488
#
#                     时间  泵冲次1(8059) spm  出口密度(8105) g/cm3  套管压力(8019) MPa  \
# 0  2020-03-19 20:00:00               0           1.60680             0.0
# 1  2020-03-19 20:00:01               0           1.60899             0.0
# 2  2020-03-19 20:00:02               0           1.61079             0.0
# 3  2020-03-19 20:00:03               0           1.61050             0.0
# 4  2020-03-19 20:00:04               0           1.60700             0.0
#
#    钻时(8020) min/m  ...  入口流量(8110) L/s  出口温度(8107) DEG.C  钻头位置(8005) m  \
# ...

# %% [markdown]
# ## 使用labelencoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['溢流'] = le.fit_transform(data['溢流'])
# data['工况'] = le.fit_transform(data['工况'])
data.head()
# Out:
#    井深(8004) m  迟到井深(8006) m  大钩高度(8008) m  全烃(8219) %  入口温度(8106) DEG.C  \
# 0      2357.1       2350.01          6.98        1.05          48.06000
# 1      2357.1       2350.01          6.98        1.05          48.06000
# 2      2357.1       2350.01          6.98        1.05          48.06000
# 3      2357.1       2350.01          6.98        1.04          48.06999
# 4      2357.1       2350.01          6.98        1.04          48.06000
#
#               时间  泵冲次1(8059) spm  出口密度(8105) g/cm3  套管压力(8019) MPa  \
# 0  2020/5/2 8:00        79.25001              1.48             0.0
# 1  2020/5/2 8:00        78.34002              1.48             0.0
# 2  2020/5/2 8:00        77.93003              1.47             0.0
# 3  2020/5/2 8:00        78.48002              1.48             0.0
# 4  2020/5/2 8:00        79.20001              1.48             0.0
#
#    钻时(8020) min/m  ...  钻压(8011) kN  入口流量(8110) L/s  出口温度(8107) DEG.C  \
# ...

# %%
data['溢流'].value_counts()
# Out:
# 0    265554
# 1     40471
# Name: 溢流, dtype: int64

# %% [markdown]
# ## 划分X和y

# %% [markdown]
# ## onehot

# %%
data_label = ['kick_0', 'kick_1']

# %%
data = encoded

# %%
X = data.drop(['时间'], axis=1)
X = X.drop(data_label, axis=1)
y = data[data_label]

# %% [markdown]
# ### labelencoder下

# %%
X = data.drop(['时间'], axis=1)
y = data[['溢流']]

# %% [markdown]
# ## 加载模型

# %%
from joblib import load
# Load the saved model from disk
clf = load('random_forest.joblib')

# %%
# Use the model for prediction
y_pred = clf.predict(X)

# %%
test_y = pd.DataFrame(y_pred)

# %%
test_y.value_counts()
# Out:
# 0    265554
# 1     40471
# dtype: int64

# %% [markdown]
# ## 准确率，召回率、f1分数，看模型效果

# %%
from sklearn.metrics import classification_report
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    265554
#            1       1.00      1.00      1.00     40471
#
#     accuracy                           1.00    306025
#    macro avg       1.00      1.00      1.00    306025
# weighted avg       1.00      1.00      1.00    306025

# %% [markdown]
# <font color='red'> 此处遇到问题，现有的这个井8中只有0,1两类，编码也为10，01,而不是0001,0010,0100,1000的四位编码，无法进行评估比较，故使用多分类器，one-vs-rest or one-vs-one <font>
